# %% [markdown]
# <span style=float:center><img src='../MSG/img/LSASAF_Name_Colour.png' alt='CM SAF' align='right' width='20%'></img>
# <span style=float:center><img src='../MSG/img/eumet_logo.png' alt='Eumetsat logo' align='center' width='30%'></img>

# %% [markdown]
# ## <span style="color:blue">**International Autumn School on Satellite Data Applications (2024)**</span>

# %% [markdown]
# **Copyright:** 2024 EUMETSAT <br>
# **License:** MIT <br>
# **Authors:** Antonio Vecoli **[vecoli@meeo.it]** (EUMETSAT/MEEO)

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h3><b>Data Download</b></h3> </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <b>PREREQUISITES </b>
#
# This notebook has the following requirement:
#   - **<a href="https://datalsasaf.lsasvcs.ipma.pt/" target="_blank">A LSA SAF Data Service account </a>** if you want to download one or more products from the LSA SAF datasets.
#
#     The registration page can be reached from the [**LSA SAF Home Page**](https://landsaf.ipma.pt/en/) where you can also find the complete catalogue describing all the available datasets.
#
# There are no prerequisite modules for this notebook.
# </div>
# <hr>

# %% [markdown]
# ### Data used

# %% [markdown]
# |Product name| **Product Description**                    | Area | Spat. Resolution (degrees) |Temp. Coverage|Temp. Resolution | Data Access|
# |:--------------------------------------------:|:----:|:---:|:---:|:---:|:---:|:---:|
# |<span style="color:blue">**MLST-AS [LSA-005]**</span>|<span style="color:blue">**MSG Land Surface Temperature - All Sky**</span>|<span style="color:blue">**MSG Disk**</span>|**0.05x0.05**|<span style="color:blue">**2020 - NRT**</span>|<span style="color:blue">**30 min**</span> |[**link**](https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-AS/)|

# %% [markdown]
# ### **Introduction**
#
# This Jupyter notebook will guide you step by step into the operations needed to select and then download a set o ftime slots for a specific LSA SAF product  included in the catalogue that is available in the [**LSA SAF Home Page**](https://landsaf.ipma.pt/en/). The registration to the **LSA SAF Data Service** will allow you to explore all the datasets and choose the temporal period of interest. Then, with your LSA SAF credentials you will be able to download the product directly in this Jupyter environment where you can open, process and visualize the retrieved data.

# %% [markdown]
# ### **Outline**
#
# * [**1.1 - Browsing the LSA SAF catalogue**](#browse)
# * [**1.2 - Accessing the LSA SAF Data Service**](#service)
# * [**1.3 - Downloading the products**](#download)

# %% [markdown]
# <hr>

# %% [markdown]
# #### **Importing required libraries**

# %%
import os  #library to use functionalities of the operating system:
#           in particular, to run command line instruction inside the code cells
#           of the notebook
import datetime as dt  # a library that allows us to work with dates and times
import pandas as pd    # a library for time series analysis

# %% [markdown]
# <hr>

# %% [markdown]
# ### <a id="browse"></a>**1.1 - Browsing the LSA SAF catalogue**

# %% [markdown]
# <span style=float:center><img src='../MSG/img/EUM_school_1.png' alt='Products' align='right' width='60%'></img>
# </span>
#
# The LSA SAF home page provides a dedicated <span style="color:blue">**Products**</span> section where the available datasets are grouped in 6 specific thematic areas. You can find this section at the following link: [**https://landsaf.ipma.pt/en/data/products/**](https://landsaf.ipma.pt/en/data/products/)
#
# Each of the areas provides a short description of the related datasets and the links to the data sources.
#
# In this notebook we show you how to download the **LST All Sky** product (official name <span style="color:red">**MLST-ASv2**</span>), but you can select other product to download.

# %% [markdown]
# ### <a id="service"></a>**1.2 - Accessing the LSA SAF Data Service**

# %% [markdown]
# <span style=float:center><img src='../MSG/img/EUM_school_2.jpg' alt='Products' align='right' width='60%'></img>
# </span>
#
# As you should already have completed the registration process for the LSA SAF Data Service, you should have received the credentials that will allow you to enter the **Data Archive** from the following page:
#
# [**https://datalsasaf.lsasvcs.ipma.pt/**](https://datalsasaf.lsasvcs.ipma.pt/)
#
#
# Here you will also find the link to a <span style="color:red">**User Guide**</span> which provides explanations and code about how to access the data with multiple approaches.

# %% [markdown]
# ### <a id="download"></a>**1.3 - Downloading the product over one day**

# %% [markdown]
# Now to implement the download operation you need to define the following variables:

# %%
username = 'USERNAME' #username of the Data Service account
password = 'PASSWORD' #password of the Data Service account
dest_folder = 'TYPE THE RELATIVE PATH OF THE DESTINATION FOLDER'  # folder where the product will be downloaded

# %%
username = '' #username of the Data Service account
mypassword = '' #password of the Data Service account
dest_folder = 'data/'  # folder where the product will be downloaded

# %% [markdown]
# Next you can choose the product you want to download

# %%
Product_name='MLST-ASv2'

# %% [markdown]
# We will donwload all files from a single day, at a given time frequency. Please note that the best temporal frequency of LSA SAF products is 15 min. Hovewever, not all the products are available at this time frequency. The user should check the LSA SAF catalogue.

# %%
start_date = dt.datetime(2023, 7, 21)
end_date = dt.datetime(2023, 7, 21)

timefreq=60

# %%
date_range = pd.date_range(start_date, end_date, freq="d")
# create a list of hours for which we have MLST-ASv2 data (every 30 minutes)
day_range = pd.date_range(date_range[0], date_range[0] + dt.timedelta(minutes=1410), freq=dt.timedelta(minutes=timefreq))
Filename_prefix='NETCDF4_LSASAF_MSG_'+Product_name+'_MSG-Disk_'
for file in date_range:
  for time in day_range:

    print(time)
    # build the file name based on the parameters
    file_name = Filename_prefix \
    + str("{:02d}".format(file.year)) \
    + str("{:02d}".format(file.month)) \
    + str("{:02d}".format(file.day)) \
    + str("{:02d}".format(time.hour)) \
    + str("{:02d}".format(time.minute)) \
    + ".nc"

    # print the file name
    #print("===========================================================================================")
    #print(file_name)
    #print("\n")

    # "year", "month" and "day" reference for folders
    year = str("{:02d}".format(file.year))
    month = str("{:02d}".format(file.month))
    day = str("{:02d}".format(file.day))
# download the "Land Surface Temperature - All Sky Version 2" file
 
    # !wget -c --no-check-certificate \
        --user=carlabarroso22 --password='carlabarroso24#' -P {dest_folder} \
        https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/{Product_name}/NETCDF/{year}/{month}/{day}/{file_name}
# Out:
# 2023-07-21 00:00:00
# --2024-10-15 17:41:25--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2023/07/21/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307210000.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3760566 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307210000.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.59M  5.69MB/s    in 0.6s
#
# 2024-10-15 17:41:26 (5.69 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307210000.nc’ saved [3760566/3760566]
#
# 2023-07-21 01:00:00
# --2024-10-15 17:41:26--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2023/07/21/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307210100.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3758683 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307210100.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.58M  4.94MB/s    in 0.7s
#
# 2024-10-15 17:41:28 (4.94 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307210100.nc’ saved [3758683/3758683]
#
# 2023-07-21 02:00:00
# --2024-10-15 17:41:28--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2023/07/21/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307210200.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3752733 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307210200.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.58M  7.33MB/s    in 0.5s
#
# 2024-10-15 17:41:29 (7.33 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307210200.nc’ saved [3752733/3752733]
#
# 2023-07-21 03:00:00
# --2024-10-15 17:41:29--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2023/07/21/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307210300.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3760848 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307210300.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.59M  5.66MB/s    in 0.6s
#
# 2024-10-15 17:41:30 (5.66 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307210300.nc’ saved [3760848/3760848]
#
# 2023-07-21 04:00:00
# --2024-10-15 17:41:30--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2023/07/21/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307210400.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3777565 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307210400.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.60M  7.06MB/s    in 0.5s
#
# 2024-10-15 17:41:31 (7.06 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307210400.nc’ saved [3777565/3777565]
#
# 2023-07-21 05:00:00
# --2024-10-15 17:41:31--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2023/07/21/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307210500.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3800691 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307210500.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.62M  7.28MB/s    in 0.5s
#
# 2024-10-15 17:41:32 (7.28 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307210500.nc’ saved [3800691/3800691]
#
# 2023-07-21 06:00:00
# --2024-10-15 17:41:32--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2023/07/21/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307210600.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3819021 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307210600.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.64M  6.56MB/s    in 0.6s
#
# 2024-10-15 17:41:34 (6.56 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307210600.nc’ saved [3819021/3819021]
#
# 2023-07-21 07:00:00
# --2024-10-15 17:41:34--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2023/07/21/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307210700.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3865975 (3.7M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307210700.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.69M  7.45MB/s    in 0.5s
#
# 2024-10-15 17:41:35 (7.45 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307210700.nc’ saved [3865975/3865975]
#
# 2023-07-21 08:00:00
# --2024-10-15 17:41:35--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2023/07/21/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307210800.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3897934 (3.7M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307210800.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.72M  7.28MB/s    in 0.5s
#
# 2024-10-15 17:41:36 (7.28 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307210800.nc’ saved [3897934/3897934]
#
# 2023-07-21 09:00:00
# --2024-10-15 17:41:36--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2023/07/21/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307210900.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3935191 (3.8M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307210900.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.75M  6.56MB/s    in 0.6s
#
# 2024-10-15 17:41:37 (6.56 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307210900.nc’ saved [3935191/3935191]
#
# 2023-07-21 10:00:00
# --2024-10-15 17:41:37--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2023/07/21/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307211000.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3973780 (3.8M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307211000.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.79M  7.65MB/s    in 0.5s
#
# 2024-10-15 17:41:38 (7.65 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307211000.nc’ saved [3973780/3973780]
#
# 2023-07-21 11:00:00
# --2024-10-15 17:41:38--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2023/07/21/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307211100.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4005902 (3.8M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307211100.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.82M  6.24MB/s    in 0.6s
#
# 2024-10-15 17:41:39 (6.24 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307211100.nc’ saved [4005902/4005902]
#
# 2023-07-21 12:00:00
# --2024-10-15 17:41:40--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2023/07/21/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307211200.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4027400 (3.8M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307211200.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.84M  2.29MB/s    in 1.7s
#
# 2024-10-15 17:41:42 (2.29 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307211200.nc’ saved [4027400/4027400]
#
# 2023-07-21 13:00:00
# --2024-10-15 17:41:42--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2023/07/21/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307211300.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4036510 (3.8M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307211300.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.85M  7.48MB/s    in 0.5s
#
# 2024-10-15 17:41:43 (7.48 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307211300.nc’ saved [4036510/4036510]
#
# 2023-07-21 14:00:00
# --2024-10-15 17:41:43--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2023/07/21/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307211400.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4017819 (3.8M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307211400.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.83M  7.78MB/s    in 0.5s
#
# 2024-10-15 17:41:44 (7.78 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307211400.nc’ saved [4017819/4017819]
#
# 2023-07-21 15:00:00
# --2024-10-15 17:41:44--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2023/07/21/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307211500.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3977882 (3.8M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307211500.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.79M  6.88MB/s    in 0.6s
#
# 2024-10-15 17:41:45 (6.88 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307211500.nc’ saved [3977882/3977882]
#
# 2023-07-21 16:00:00
# --2024-10-15 17:41:45--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2023/07/21/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307211600.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3951865 (3.8M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307211600.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.77M  6.63MB/s    in 0.6s
#
# 2024-10-15 17:41:47 (6.63 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307211600.nc’ saved [3951865/3951865]
#
# 2023-07-21 17:00:00
# --2024-10-15 17:41:47--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2023/07/21/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307211700.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3920873 (3.7M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307211700.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.74M  6.69MB/s    in 0.6s
#
# 2024-10-15 17:41:48 (6.69 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307211700.nc’ saved [3920873/3920873]
#
# 2023-07-21 18:00:00
# --2024-10-15 17:41:48--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2023/07/21/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307211800.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3900458 (3.7M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307211800.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.72M  7.52MB/s    in 0.5s
#
# 2024-10-15 17:41:49 (7.52 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307211800.nc’ saved [3900458/3900458]
#
# 2023-07-21 19:00:00
# --2024-10-15 17:41:49--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2023/07/21/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307211900.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3878371 (3.7M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307211900.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.70M  6.62MB/s    in 0.6s
#
# 2024-10-15 17:41:50 (6.62 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307211900.nc’ saved [3878371/3878371]
#
# 2023-07-21 20:00:00
# --2024-10-15 17:41:50--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2023/07/21/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307212000.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3849356 (3.7M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307212000.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.67M  1.87MB/s    in 2.0s
#
# 2024-10-15 17:41:53 (1.87 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307212000.nc’ saved [3849356/3849356]
#
# 2023-07-21 21:00:00
# --2024-10-15 17:41:53--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2023/07/21/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307212100.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3840914 (3.7M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307212100.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.66M  4.58MB/s    in 0.8s
#
# 2024-10-15 17:41:54 (4.58 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307212100.nc’ saved [3840914/3840914]
#
# 2023-07-21 22:00:00
# --2024-10-15 17:41:54--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2023/07/21/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307212200.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3832556 (3.7M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307212200.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.65M  5.18MB/s    in 0.7s
#
# 2024-10-15 17:41:56 (5.18 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307212200.nc’ saved [3832556/3832556]
#
# 2023-07-21 23:00:00
# --2024-10-15 17:41:56--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2023/07/21/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307212300.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3841181 (3.7M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307212300.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.66M  6.98MB/s    in 0.5s
#
# 2024-10-15 17:41:57 (6.98 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202307212300.nc’ saved [3841181/3841181]

# %% [markdown]
# <hr>

# %% [markdown]
# <span style=float:center><img src='../MSG/img/LSASAF_Name_Colour.png' alt='LSA SAF' align='right' width='20%'></img>
# <span style=float:center><img src='../MSG/img/eumet_logo.png' alt='Eumetsat logo' align='center' width='20%'></img>
