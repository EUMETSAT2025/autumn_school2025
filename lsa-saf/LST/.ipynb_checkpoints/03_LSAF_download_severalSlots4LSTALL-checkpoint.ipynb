# %% [markdown]
# <span style=float:center><img src='../img/LSASAF_Name_Colour.png' alt='CM SAF' align='right' width='20%'></img>
# <span style=float:center><img src='../img/eumet_logo.png' alt='Eumetsat logo' align='center' width='30%'></img>

# %% [markdown]
# ## <span style="color:blue">**International Autumn School on Satellite Data Applications (2024)**</span>

# %% [markdown]
# **Copyright:** 2024 EUMETSAT <br>
# **License:** MIT <br>
# **Authors:** Antonio Vecoli **[vecoli@meeo.it]** (EUMETSAT/MEEO)

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h3><b>Data Download</b></h3> </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <b>PREREQUISITES </b>
#
# This notebook has the following requirement:
#   - **<a href="https://datalsasaf.lsasvcs.ipma.pt/" target="_blank">A LSA SAF Data Service account </a>** if you want to download one or more products from the LSA SAF datasets.
#
#     The registration page can be reached from the [**LSA SAF Home Page**](https://landsaf.ipma.pt/en/) where you can also find the complete catalogue describing all the available datasets.
#
# There are no prerequisite modules for this notebook.
# </div>
# <hr>

# %% [markdown]
# ### Data used

# %% [markdown]
# |Product name| **Product Description**                    | Area | Spat. Resolution (degrees) |Temp. Coverage|Temp. Resolution | Data Access|
# |:--------------------------------------------:|:----:|:---:|:---:|:---:|:---:|:---:|
# |<span style="color:blue">**MLST-AS [LSA-005]**</span>|<span style="color:blue">**MSG Land Surface Temperature - All Sky**</span>|<span style="color:blue">**MSG Disk**</span>|**0.05x0.05**|<span style="color:blue">**2020 - NRT**</span>|<span style="color:blue">**30 min**</span> |[**link**](https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-AS/)|

# %% [markdown]
# ### **Introduction**
#
# This Jupyter notebook will guide you step by step into the operations needed to select and then download a set o ftime slots for a specific LSA SAF product  included in the catalogue that is available in the [**LSA SAF Home Page**](https://landsaf.ipma.pt/en/). The registration to the **LSA SAF Data Service** will allow you to explore all the datasets and choose the temporal period of interest. Then, with your LSA SAF credentials you will be able to download the product directly in this Jupyter environment where you can open, process and visualize the retrieved data.

# %% [markdown]
# ### **Outline**
#
# * [**1.1 - Browsing the LSA SAF catalogue**](#browse)
# * [**1.2 - Accessing the LSA SAF Data Service**](#service)
# * [**1.3 - Downloading the products**](#download)

# %% [markdown]
# <hr>

# %% [markdown]
# #### **Importing required libraries**

# %%
import os  #library to use functionalities of the operating system:
#           in particular, to run command line instruction inside the code cells
#           of the notebook
import datetime as dt  # a library that allows us to work with dates and times
import pandas as pd    # a library for time series analysis

# %% [markdown]
# <hr>

# %% [markdown]
# ### <a id="browse"></a>**1.1 - Browsing the LSA SAF catalogue**

# %% [markdown]
# <span style=float:center><img src='../img/EUM_school_1.png' alt='Products' align='right' width='60%'></img>
# </span>
#
# The LSA SAF home page provides a dedicated <span style="color:blue">**Products**</span> section where the available datasets are grouped in 6 specific thematic areas. You can find this section at the following link: [**https://landsaf.ipma.pt/en/data/products/**](https://landsaf.ipma.pt/en/data/products/)
#
# Each of the areas provides a short description of the related datasets and the links to the data sources.
#
# In this notebook we show you how to download the **LST All Sky** product (official name <span style="color:red">**MLST-ASv2**</span>), but you can select other product to download.

# %% [markdown]
# ### <a id="service"></a>**1.2 - Accessing the LSA SAF Data Service**

# %% [markdown]
# <span style=float:center><img src='../img/EUM_school_2.jpg' alt='Products' align='right' width='60%'></img>
# </span>
#
# As you should already have completed the registration process for the LSA SAF Data Service, you should have received the credentials that will allow you to enter the **Data Archive** from the following page:
#
# [**https://datalsasaf.lsasvcs.ipma.pt/**](https://datalsasaf.lsasvcs.ipma.pt/)
#
#
# Here you will also find the link to a <span style="color:red">**User Guide**</span> which provides explanations and code about how to access the data with multiple approaches.

# %% [markdown]
# ### <a id="download"></a>**1.3 - Downloading the product for several slots**

# %% [markdown]
# Now to implement the download operation you need to define the following variables:

# %%
username = 'USERNAME' #username of the Data Service account
password = 'PASSWORD' #password of the Data Service account
dest_folder = 'TYPE THE RELATIVE PATH OF THE DESTINATION FOLDER'  # folder where the product will be downloaded

# %%
username = '' #username of the Data Service account
mypassword = '' #password of the Data Service account
dest_folder = 'data/'  # folder where the product will be downloaded

# %% [markdown]
# Next you can choose the product you want to download

# %%
Product_name='MLST-ASv2'

# %% [markdown]
# We will donwload all files from a single day, at a given time frequency. Please note that the best temporal frequency of LSA SAF products is 15 min. Hovewever, not all the products are available at this time frequency. The user should check the LSA SAF catalogue.

# %%
#start_date = dt.datetime(2023, 7, 15)
#end_date = dt.datetime(2023, 7, 20)
#start_date=dt.datetime(2022, 8, 1)
#end_date=dt.datetime(2022, 8, 7)
start_date=dt.datetime(2024, 9, 15)
end_date=dt.datetime(2024, 9, 18)
start_date=dt.datetime(2022, 6, 30)
end_date=dt.datetime(2022, 7, 20)

timefreq=30

# %%
date_range = pd.date_range(start_date, end_date, freq="d")
# create a list of hours for which we have MLST-ASv2 data (every 30 minutes)
day_range = pd.date_range(date_range[0], date_range[0] + dt.timedelta(minutes=1410), freq=dt.timedelta(minutes=timefreq))
Filename_prefix='NETCDF4_LSASAF_MSG_'+Product_name+'_MSG-Disk_'
for file in date_range:
  for time in day_range:

    print(time)
    # build the file name based on the parameters
    file_name = Filename_prefix \
    + str("{:02d}".format(file.year)) \
    + str("{:02d}".format(file.month)) \
    + str("{:02d}".format(file.day)) \
    + str("{:02d}".format(time.hour)) \
    + str("{:02d}".format(time.minute)) \
    + ".nc"

    # print the file name
    #print("===========================================================================================")
    #print(file_name)
    #print("\n")

    # "year", "month" and "day" reference for folders
    year = str("{:02d}".format(file.year))
    month = str("{:02d}".format(file.month))
    day = str("{:02d}".format(file.day))
# download the "Land Surface Temperature - All Sky Version 2" file
 
    # !wget -c --no-check-certificate \
        --user=carlabarroso22 --password='carlabarroso24#' -P {dest_folder} \
        https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/{Product_name}/NETCDF/{year}/{month}/{day}/{file_name}
# Out:
# 2024-06-11 00:00:00
# --2024-10-22 14:19:28--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110000.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3744860 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110000.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.57M  6.24MB/s    in 0.6s
#
# 2024-10-22 14:19:29 (6.24 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110000.nc’ saved [3744860/3744860]
#
# 2024-06-11 00:30:00
# --2024-10-22 14:19:29--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110030.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3734317 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110030.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.56M  7.06MB/s    in 0.5s
#
# 2024-10-22 14:19:30 (7.06 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110030.nc’ saved [3734317/3734317]
#
# 2024-06-11 01:00:00
# --2024-10-22 14:19:30--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110100.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3726550 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110100.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.55M  7.27MB/s    in 0.5s
#
# 2024-10-22 14:19:31 (7.27 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110100.nc’ saved [3726550/3726550]
#
# 2024-06-11 01:30:00
# --2024-10-22 14:19:31--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110130.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3717647 (3.5M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110130.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.54M  6.97MB/s    in 0.5s
#
# 2024-10-22 14:19:32 (6.97 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110130.nc’ saved [3717647/3717647]
#
# 2024-06-11 02:00:00
# --2024-10-22 14:19:32--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110200.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3718303 (3.5M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110200.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.55M  7.21MB/s    in 0.5s
#
# 2024-10-22 14:19:33 (7.21 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110200.nc’ saved [3718303/3718303]
#
# 2024-06-11 02:30:00
# --2024-10-22 14:19:33--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110230.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3713924 (3.5M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110230.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.54M  6.26MB/s    in 0.6s
#
# 2024-10-22 14:19:35 (6.26 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110230.nc’ saved [3713924/3713924]
#
# 2024-06-11 03:00:00
# --2024-10-22 14:19:35--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110300.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3710017 (3.5M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110300.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.54M  6.96MB/s    in 0.5s
#
# 2024-10-22 14:19:36 (6.96 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110300.nc’ saved [3710017/3710017]
#
# 2024-06-11 03:30:00
# --2024-10-22 14:19:36--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110330.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3707020 (3.5M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110330.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.54M  7.17MB/s    in 0.5s
#
# 2024-10-22 14:19:37 (7.17 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110330.nc’ saved [3707020/3707020]
#
# 2024-06-11 04:00:00
# --2024-10-22 14:19:37--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110400.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3711727 (3.5M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110400.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.54M  7.26MB/s    in 0.5s
#
# 2024-10-22 14:19:38 (7.26 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110400.nc’ saved [3711727/3711727]
#
# 2024-06-11 04:30:00
# --2024-10-22 14:19:38--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110430.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3716085 (3.5M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110430.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.54M  7.27MB/s    in 0.5s
#
# 2024-10-22 14:19:39 (7.27 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110430.nc’ saved [3716085/3716085]
#
# 2024-06-11 05:00:00
# --2024-10-22 14:19:39--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110500.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3727780 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110500.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.55M  6.92MB/s    in 0.5s
#
# 2024-10-22 14:19:40 (6.92 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110500.nc’ saved [3727780/3727780]
#
# 2024-06-11 05:30:00
# --2024-10-22 14:19:40--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110530.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3739316 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110530.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.57M  7.30MB/s    in 0.5s
#
# 2024-10-22 14:19:41 (7.30 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110530.nc’ saved [3739316/3739316]
#
# 2024-06-11 06:00:00
# --2024-10-22 14:19:41--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110600.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3754919 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110600.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.58M  7.32MB/s    in 0.5s
#
# 2024-10-22 14:19:42 (7.32 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110600.nc’ saved [3754919/3754919]
#
# 2024-06-11 06:30:00
# --2024-10-22 14:19:42--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110630.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3769338 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110630.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.59M  7.08MB/s    in 0.5s
#
# 2024-10-22 14:19:44 (7.08 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110630.nc’ saved [3769338/3769338]
#
# 2024-06-11 07:00:00
# --2024-10-22 14:19:44--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110700.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3798802 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110700.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.62M  6.54MB/s    in 0.6s
#
# 2024-10-22 14:19:45 (6.54 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110700.nc’ saved [3798802/3798802]
#
# 2024-06-11 07:30:00
# --2024-10-22 14:19:45--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110730.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3814790 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110730.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.64M  6.20MB/s    in 0.6s
#
# 2024-10-22 14:19:46 (6.20 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110730.nc’ saved [3814790/3814790]
#
# 2024-06-11 08:00:00
# --2024-10-22 14:19:46--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110800.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3836129 (3.7M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110800.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.66M  2.64MB/s    in 1.4s
#
# 2024-10-22 14:19:48 (2.64 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110800.nc’ saved [3836129/3836129]
#
# 2024-06-11 08:30:00
# --2024-10-22 14:19:48--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110830.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3856660 (3.7M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110830.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.68M  6.45MB/s    in 0.6s
#
# 2024-10-22 14:19:49 (6.45 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110830.nc’ saved [3856660/3856660]
#
# 2024-06-11 09:00:00
# --2024-10-22 14:19:49--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110900.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3877964 (3.7M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110900.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.70M  6.56MB/s    in 0.6s
#
# 2024-10-22 14:19:50 (6.56 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110900.nc’ saved [3877964/3877964]
#
# 2024-06-11 09:30:00
# --2024-10-22 14:19:50--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110930.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3897232 (3.7M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110930.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.72M  7.47MB/s    in 0.5s
#
# 2024-10-22 14:19:51 (7.47 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406110930.nc’ saved [3897232/3897232]
#
# 2024-06-11 10:00:00
# --2024-10-22 14:19:52--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111000.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3916818 (3.7M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111000.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.74M  4.43MB/s    in 0.8s
#
# 2024-10-22 14:19:53 (4.43 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111000.nc’ saved [3916818/3916818]
#
# 2024-06-11 10:30:00
# --2024-10-22 14:19:53--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111030.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3940603 (3.8M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111030.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.76M  7.46MB/s    in 0.5s
#
# 2024-10-22 14:19:54 (7.46 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111030.nc’ saved [3940603/3940603]
#
# 2024-06-11 11:00:00
# --2024-10-22 14:19:54--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111100.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3951647 (3.8M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111100.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.77M  6.01MB/s    in 0.6s
#
# 2024-10-22 14:19:55 (6.01 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111100.nc’ saved [3951647/3951647]
#
# 2024-06-11 11:30:00
# --2024-10-22 14:19:55--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111130.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3961416 (3.8M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111130.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.78M  7.67MB/s    in 0.5s
#
# 2024-10-22 14:19:56 (7.67 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111130.nc’ saved [3961416/3961416]
#
# 2024-06-11 12:00:00
# --2024-10-22 14:19:56--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111200.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3975697 (3.8M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111200.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.79M  6.92MB/s    in 0.5s
#
# 2024-10-22 14:19:58 (6.92 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111200.nc’ saved [3975697/3975697]
#
# 2024-06-11 12:30:00
# --2024-10-22 14:19:58--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111230.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3983933 (3.8M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111230.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.80M  7.49MB/s    in 0.5s
#
# 2024-10-22 14:19:59 (7.49 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111230.nc’ saved [3983933/3983933]
#
# 2024-06-11 13:00:00
# --2024-10-22 14:19:59--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111300.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3994463 (3.8M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111300.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.81M  7.78MB/s    in 0.5s
#
# 2024-10-22 14:20:00 (7.78 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111300.nc’ saved [3994463/3994463]
#
# 2024-06-11 13:30:00
# --2024-10-22 14:20:00--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111330.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3995595 (3.8M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111330.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.81M  6.73MB/s    in 0.6s
#
# 2024-10-22 14:20:01 (6.73 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111330.nc’ saved [3995595/3995595]
#
# 2024-06-11 14:00:00
# --2024-10-22 14:20:01--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111400.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3985530 (3.8M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111400.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.80M  7.51MB/s    in 0.5s
#
# 2024-10-22 14:20:02 (7.51 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111400.nc’ saved [3985530/3985530]
#
# 2024-06-11 14:30:00
# --2024-10-22 14:20:02--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111430.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3981284 (3.8M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111430.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.80M  7.62MB/s    in 0.5s
#
# 2024-10-22 14:20:03 (7.62 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111430.nc’ saved [3981284/3981284]
#
# 2024-06-11 15:00:00
# --2024-10-22 14:20:03--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111500.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3986786 (3.8M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111500.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.80M  7.48MB/s    in 0.5s
#
# 2024-10-22 14:20:04 (7.48 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111500.nc’ saved [3986786/3986786]
#
# 2024-06-11 15:30:00
# --2024-10-22 14:20:04--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111530.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3995750 (3.8M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111530.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.81M  7.79MB/s    in 0.5s
#
# 2024-10-22 14:20:05 (7.79 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111530.nc’ saved [3995750/3995750]
#
# 2024-06-11 16:00:00
# --2024-10-22 14:20:06--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111600.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3987092 (3.8M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111600.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.80M  7.37MB/s    in 0.5s
#
# 2024-10-22 14:20:07 (7.37 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111600.nc’ saved [3987092/3987092]
#
# 2024-06-11 16:30:00
# --2024-10-22 14:20:07--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111630.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3985012 (3.8M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111630.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.80M  7.75MB/s    in 0.5s
#
# 2024-10-22 14:20:08 (7.75 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111630.nc’ saved [3985012/3985012]
#
# 2024-06-11 17:00:00
# --2024-10-22 14:20:08--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111700.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3966379 (3.8M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111700.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.78M  7.51MB/s    in 0.5s
#
# 2024-10-22 14:20:09 (7.51 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111700.nc’ saved [3966379/3966379]
#
# 2024-06-11 17:30:00
# --2024-10-22 14:20:09--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111730.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3957365 (3.8M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111730.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.77M  6.25MB/s    in 0.6s
#
# 2024-10-22 14:20:10 (6.25 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111730.nc’ saved [3957365/3957365]
#
# 2024-06-11 18:00:00
# --2024-10-22 14:20:10--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111800.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3947059 (3.8M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111800.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.76M  5.42MB/s    in 0.7s
#
# 2024-10-22 14:20:11 (5.42 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111800.nc’ saved [3947059/3947059]
#
# 2024-06-11 18:30:00
# --2024-10-22 14:20:12--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111830.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3926263 (3.7M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111830.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.74M  7.41MB/s    in 0.5s
#
# 2024-10-22 14:20:13 (7.41 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111830.nc’ saved [3926263/3926263]
#
# 2024-06-11 19:00:00
# --2024-10-22 14:20:13--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111900.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3908593 (3.7M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111900.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.73M  7.59MB/s    in 0.5s
#
# 2024-10-22 14:20:14 (7.59 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111900.nc’ saved [3908593/3908593]
#
# 2024-06-11 19:30:00
# --2024-10-22 14:20:14--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111930.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3881811 (3.7M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111930.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.70M  6.10MB/s    in 0.6s
#
# 2024-10-22 14:20:15 (6.10 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406111930.nc’ saved [3881811/3881811]
#
# 2024-06-11 20:00:00
# --2024-10-22 14:20:15--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406112000.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3857375 (3.7M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406112000.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.68M  7.24MB/s    in 0.5s
#
# 2024-10-22 14:20:16 (7.24 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406112000.nc’ saved [3857375/3857375]
#
# 2024-06-11 20:30:00
# --2024-10-22 14:20:16--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406112030.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3830708 (3.7M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406112030.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.65M  6.45MB/s    in 0.6s
#
# 2024-10-22 14:20:17 (6.45 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406112030.nc’ saved [3830708/3830708]
#
# 2024-06-11 21:00:00
# --2024-10-22 14:20:17--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406112100.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3816363 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406112100.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.64M  7.19MB/s    in 0.5s
#
# 2024-10-22 14:20:18 (7.19 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406112100.nc’ saved [3816363/3816363]
#
# 2024-06-11 21:30:00
# --2024-10-22 14:20:18--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406112130.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3800226 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406112130.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.62M  7.24MB/s    in 0.5s
#
# 2024-10-22 14:20:19 (7.24 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406112130.nc’ saved [3800226/3800226]
#
# 2024-06-11 22:00:00
# --2024-10-22 14:20:20--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406112200.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3793667 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406112200.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.62M  7.13MB/s    in 0.5s
#
# 2024-10-22 14:20:21 (7.13 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406112200.nc’ saved [3793667/3793667]
#
# 2024-06-11 22:30:00
# --2024-10-22 14:20:21--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406112230.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3778558 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406112230.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.60M  5.95MB/s    in 0.6s
#
# 2024-10-22 14:20:22 (5.95 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406112230.nc’ saved [3778558/3778558]
#
# 2024-06-11 23:00:00
# --2024-10-22 14:20:22--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406112300.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3765834 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406112300.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.59M  7.37MB/s    in 0.5s
#
# 2024-10-22 14:20:23 (7.37 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406112300.nc’ saved [3765834/3765834]
#
# 2024-06-11 23:30:00
# --2024-10-22 14:20:23--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/11/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406112330.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3757837 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406112330.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.58M  3.77MB/s    in 1.0s
#
# 2024-10-22 14:20:24 (3.77 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406112330.nc’ saved [3757837/3757837]
#
# 2024-06-11 00:00:00
# --2024-10-22 14:20:25--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/12/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406120000.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3863705 (3.7M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406120000.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.68M  7.33MB/s    in 0.5s
#
# 2024-10-22 14:20:26 (7.33 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406120000.nc’ saved [3863705/3863705]
#
# 2024-06-11 00:30:00
# --2024-10-22 14:20:26--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/12/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406120030.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3860376 (3.7M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406120030.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.68M  7.55MB/s    in 0.5s
#
# 2024-10-22 14:20:27 (7.55 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406120030.nc’ saved [3860376/3860376]
#
# 2024-06-11 01:00:00
# --2024-10-22 14:20:27--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/12/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406120100.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3857792 (3.7M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406120100.nc’
#
# ...
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3985300 (3.8M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406151530.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.80M  5.70MB/s    in 0.7s
#
# 2024-10-22 14:23:55 (5.70 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406151530.nc’ saved [3985300/3985300]
#
# 2024-06-11 16:00:00
# --2024-10-22 14:23:55--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/15/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406151600.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3981137 (3.8M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406151600.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.80M  7.44MB/s    in 0.5s
#
# 2024-10-22 14:23:56 (7.44 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406151600.nc’ saved [3981137/3981137]
#
# 2024-06-11 16:30:00
# --2024-10-22 14:23:57--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/15/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406151630.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3978104 (3.8M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406151630.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.79M  7.73MB/s    in 0.5s
#
# 2024-10-22 14:23:58 (7.73 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406151630.nc’ saved [3978104/3978104]
#
# 2024-06-11 17:00:00
# --2024-10-22 14:23:58--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/15/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406151700.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3955648 (3.8M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406151700.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.77M  7.61MB/s    in 0.5s
#
# 2024-10-22 14:23:59 (7.61 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406151700.nc’ saved [3955648/3955648]
#
# 2024-06-11 17:30:00
# --2024-10-22 14:23:59--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/15/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406151730.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3938636 (3.8M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406151730.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.76M  6.16MB/s    in 0.6s
#
# 2024-10-22 14:24:00 (6.16 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406151730.nc’ saved [3938636/3938636]
#
# 2024-06-11 18:00:00
# --2024-10-22 14:24:00--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/15/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406151800.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3931978 (3.7M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406151800.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.75M  7.70MB/s    in 0.5s
#
# 2024-10-22 14:24:01 (7.70 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406151800.nc’ saved [3931978/3931978]
#
# 2024-06-11 18:30:00
# --2024-10-22 14:24:01--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/15/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406151830.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3923040 (3.7M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406151830.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.74M  7.65MB/s    in 0.5s
#
# 2024-10-22 14:24:02 (7.65 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406151830.nc’ saved [3923040/3923040]
#
# 2024-06-11 19:00:00
# --2024-10-22 14:24:02--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/15/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406151900.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3908900 (3.7M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406151900.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.73M  6.70MB/s    in 0.6s
#
# 2024-10-22 14:24:03 (6.70 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406151900.nc’ saved [3908900/3908900]
#
# 2024-06-11 19:30:00
# --2024-10-22 14:24:03--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/15/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406151930.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3894322 (3.7M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406151930.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.71M  7.30MB/s    in 0.5s
#
# 2024-10-22 14:24:04 (7.30 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406151930.nc’ saved [3894322/3894322]
#
# 2024-06-11 20:00:00
# --2024-10-22 14:24:05--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/15/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406152000.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3876623 (3.7M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406152000.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.70M  7.55MB/s    in 0.5s
#
# 2024-10-22 14:24:06 (7.55 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406152000.nc’ saved [3876623/3876623]
#
# 2024-06-11 20:30:00
# --2024-10-22 14:24:06--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/15/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406152030.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3857704 (3.7M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406152030.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.68M  6.45MB/s    in 0.6s
#
# 2024-10-22 14:24:07 (6.45 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406152030.nc’ saved [3857704/3857704]
#
# 2024-06-11 21:00:00
# --2024-10-22 14:24:07--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/15/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406152100.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3847296 (3.7M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406152100.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.67M  6.44MB/s    in 0.6s
#
# 2024-10-22 14:24:08 (6.44 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406152100.nc’ saved [3847296/3847296]
#
# 2024-06-11 21:30:00
# --2024-10-22 14:24:08--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/15/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406152130.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3836933 (3.7M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406152130.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.66M  6.55MB/s    in 0.6s
#
# 2024-10-22 14:24:09 (6.55 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406152130.nc’ saved [3836933/3836933]
#
# 2024-06-11 22:00:00
# --2024-10-22 14:24:09--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/15/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406152200.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3833700 (3.7M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406152200.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.66M  6.29MB/s    in 0.6s
#
# 2024-10-22 14:24:10 (6.29 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406152200.nc’ saved [3833700/3833700]
#
# 2024-06-11 22:30:00
# --2024-10-22 14:24:10--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/15/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406152230.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3828163 (3.7M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406152230.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.65M  6.55MB/s    in 0.6s
#
# 2024-10-22 14:24:12 (6.55 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406152230.nc’ saved [3828163/3828163]
#
# 2024-06-11 23:00:00
# --2024-10-22 14:24:12--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/15/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406152300.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3831295 (3.7M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406152300.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.65M  7.11MB/s    in 0.5s
#
# 2024-10-22 14:24:13 (7.11 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406152300.nc’ saved [3831295/3831295]
#
# 2024-06-11 23:30:00
# --2024-10-22 14:24:13--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2024/06/15/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406152330.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3826040 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406152330.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.65M  7.24MB/s    in 0.5s
#
# 2024-10-22 14:24:14 (7.24 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202406152330.nc’ saved [3826040/3826040]

# %% [markdown]
# <hr>

# %% [markdown]
# <hr>

# %% [markdown]
# <span style=float:center><img src='../img/LSASAF_Name_Colour.png' alt='LSA SAF' align='right' width='20%'></img>
# <span style=float:center><img src='../img/eumet_logo.png' alt='Eumetsat logo' align='center' width='20%'></img>
