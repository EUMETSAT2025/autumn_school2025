# %% [markdown]
# <span style=float:center><img src='../img/LSASAF_Name_Colour.png' alt='CM SAF' align='right' width='20%'></img>
# <span style=float:center><img src='../img/eumet_logo.png' alt='Eumetsat logo' align='center' width='30%'></img>

# %% [markdown]
# ## <span style="color:blue">**International Autumn School on Satellite Data Applications (2024)**</span>

# %% [markdown]
# **Copyright:** 2024 EUMETSAT <br>
# **License:** MIT <br>
# **Authors:** Antonio Vecoli **[vecoli@meeo.it]** (EUMETSAT/MEEO)

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h3><b>Data Download</b></h3> </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <b>PREREQUISITES </b>
#
# This notebook has the following requirement:
#   - **<a href="https://datalsasaf.lsasvcs.ipma.pt/" target="_blank">A LSA SAF Data Service account </a>** if you want to download one or more products from the LSA SAF datasets.
#
#     The registration page can be reached from the [**LSA SAF Home Page**](https://landsaf.ipma.pt/en/) where you can also find the complete catalogue describing all the available datasets.
#
# There are no prerequisite modules for this notebook.
# </div>
# <hr>

# %% [markdown]
# ### Data used

# %% [markdown]
# |Product name| **Product Description**                    | Area | Spat. Resolution (degrees) |Temp. Coverage|Temp. Resolution | Data Access|
# |:--------------------------------------------:|:----:|:---:|:---:|:---:|:---:|:---:|
# |<span style="color:blue">**MLST-AS [LSA-005]**</span>|<span style="color:blue">**MSG Land Surface Temperature - All Sky**</span>|<span style="color:blue">**MSG Disk**</span>|**0.05x0.05**|<span style="color:blue">**2020 - NRT**</span>|<span style="color:blue">**30 min**</span> |[**link**](https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-AS/)|

# %% [markdown]
# ### **Introduction**
#
# This Jupyter notebook will guide you step by step into the operations needed to select and then download a set o ftime slots for a specific LSA SAF product  included in the catalogue that is available in the [**LSA SAF Home Page**](https://landsaf.ipma.pt/en/). The registration to the **LSA SAF Data Service** will allow you to explore all the datasets and choose the temporal period of interest. Then, with your LSA SAF credentials you will be able to download the product directly in this Jupyter environment where you can open, process and visualize the retrieved data.

# %% [markdown]
# ### **Outline**
#
# * [**1.1 - Browsing the LSA SAF catalogue**](#browse)
# * [**1.2 - Accessing the LSA SAF Data Service**](#service)
# * [**1.3 - Downloading the products**](#download)

# %% [markdown]
# <hr>

# %% [markdown]
# #### **Importing required libraries**

# %%
import os  #library to use functionalities of the operating system:
#           in particular, to run command line instruction inside the code cells
#           of the notebook
import datetime as dt  # a library that allows us to work with dates and times
import pandas as pd    # a library for time series analysis

# %% [markdown]
# <hr>

# %% [markdown]
# ### <a id="browse"></a>**1.1 - Browsing the LSA SAF catalogue**

# %% [markdown]
# <span style=float:center><img src='../img/EUM_school_1.png' alt='Products' align='right' width='60%'></img>
# </span>
#
# The LSA SAF home page provides a dedicated <span style="color:blue">**Products**</span> section where the available datasets are grouped in 6 specific thematic areas. You can find this section at the following link: [**https://landsaf.ipma.pt/en/data/products/**](https://landsaf.ipma.pt/en/data/products/)
#
# Each of the areas provides a short description of the related datasets and the links to the data sources.
#
# In this notebook we show you how to download the **LST All Sky** product (official name <span style="color:red">**MLST-ASv2**</span>), but you can select other product to download.

# %% [markdown]
# ### <a id="service"></a>**1.2 - Accessing the LSA SAF Data Service**

# %% [markdown]
# <span style=float:center><img src='../img/EUM_school_2.jpg' alt='Products' align='right' width='60%'></img>
# </span>
#
# As you should already have completed the registration process for the LSA SAF Data Service, you should have received the credentials that will allow you to enter the **Data Archive** from the following page:
#
# [**https://datalsasaf.lsasvcs.ipma.pt/**](https://datalsasaf.lsasvcs.ipma.pt/)
#
#
# Here you will also find the link to a <span style="color:red">**User Guide**</span> which provides explanations and code about how to access the data with multiple approaches.

# %% [markdown]
# ### <a id="download"></a>**1.3 - Downloading the product for several slots**

# %% [markdown]
# Now to implement the download operation you need to define the following variables:

# %%
username = 'carlabarroso22' #username of the Data Service account
password = 'Carlabarroso26#' #password of the Data Service account
#dest_folder = 'TYPE THE RELATIVE PATH OF THE DESTINATION FOLDER'  # folder where the product will be downloaded
dest_folder = 'data/'

# %%
username = '' #username of the Data Service account
mypassword = '' #password of the Data Service account
dest_folder = 'data/'  # folder where the product will be downloaded

# %% [markdown]
# Next you can choose the product you want to download

# %%
Product_name='MLST-ASv2'

# %% [markdown]
# We will donwload all files from a single day, at a given time frequency. Please note that the best temporal frequency of LSA SAF products is 15 min. Hovewever, not all the products are available at this time frequency. The user should check the LSA SAF catalogue.

# %%
#start_date=dt.datetime(2024, 9, 15)
#end_date=dt.datetime(2024, 9, 18)
start_date=dt.datetime(2022, 6, 30)
end_date=dt.datetime(2022, 7, 20)

timefreq=30

# %%
date_range = pd.date_range(start_date, end_date, freq="d")
# create a list of hours for which we have MLST-ASv2 data (every 30 minutes)
day_range = pd.date_range(date_range[0], date_range[0] + dt.timedelta(minutes=1410), freq=dt.timedelta(minutes=timefreq))
Filename_prefix='NETCDF4_LSASAF_MSG_'+Product_name+'_MSG-Disk_'
for file in date_range:
  for time in day_range:

    print(time)
    # build the file name based on the parameters
    file_name = Filename_prefix \
    + str("{:02d}".format(file.year)) \
    + str("{:02d}".format(file.month)) \
    + str("{:02d}".format(file.day)) \
    + str("{:02d}".format(time.hour)) \
    + str("{:02d}".format(time.minute)) \
    + ".nc"

    # print the file name
    #print("===========================================================================================")
    #print(file_name)
    #print("\n")

    # "year", "month" and "day" reference for folders
    year = str("{:02d}".format(file.year))
    month = str("{:02d}".format(file.month))
    day = str("{:02d}".format(file.day))
# download the "Land Surface Temperature - All Sky Version 2" file
 
    # !wget -c --no-check-certificate \
        --user=carlabarroso22 --password='Carlabarroso26#' -P {dest_folder} \
        https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/{Product_name}/NETCDF/{year}/{month}/{day}/{file_name}
# Out:
# 2022-06-30 00:00:00
# --2025-10-22 15:47:05--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2022/06/30/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202206300000.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3739573 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202206300000.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.57M  7.69MB/s    in 0.5s
#
# 2025-10-22 15:47:06 (7.69 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202206300000.nc’ saved [3739573/3739573]
#
# 2022-06-30 00:30:00
# --2025-10-22 15:47:06--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2022/06/30/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202206300030.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3736049 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202206300030.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.56M  7.01MB/s    in 0.5s
#
# 2025-10-22 15:47:07 (7.01 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202206300030.nc’ saved [3736049/3736049]
#
# 2022-06-30 01:00:00
# --2025-10-22 15:47:07--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2022/06/30/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202206300100.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3736621 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202206300100.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.56M  7.69MB/s    in 0.5s
#
# 2025-10-22 15:47:08 (7.69 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202206
nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.55M  1.94MB/s    in 1.8s
#
# 2025-10-22 15:47:57 (1.94 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202206302300.nc’ saved [3725540/3725540]
#
# 2022-06-30 23:30:00
# --2025-10-22 15:47:58--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2022/06/30/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202206302330.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3723813 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202206302330.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.55M  7.66MB/s    in 0.5s
#
# 2025-10-22 15:47:59 (7.66 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202206302330.nc’ saved [3723813/3723813]
#
# 2022-06-30 00:00:00
# --2025-10-22 15:47:59--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2022/07/01/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207010000.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3738953 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207010000.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.57M  7.78MB/s    in 0.5s
#
# 2025-10-22 15:48:00 (7.78 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207010000.nc’ saved [3738953/3738953]
#
# 2022-06-30 00:30:00
# --2025-10-22 15:48:00--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2022/07/01/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207010030.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3733445 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207010030.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.56M  7.77MB/s    in 0.5s
#
# 2025-10-22 15:48:01 (7.77 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207010030.nc’ saved [3733445/3733445]
#
# 2022-06-30 01:00:00
# --2025-10-22 15:48:01--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2022/07/01/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207010100.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3740099 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207010100.nc’
#
# ...
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3434732 (3.3M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207022000.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.28M  7.17MB/s    in 0.5s
#
# 2025-10-22 15:49:35 (7.17 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207022000.nc’ saved [3434732/3434732]
#
# 2022-06-30 20:30:00
# --2025-10-22 15:49:35--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2022/07/02/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207022030.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3791474 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207022030.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.62M  7.88MB/s    in 0.5s
#
# 2025-10-22 15:49:36 (7.88 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207022030.nc’ saved [3791474/3791474]
#
# 2022-06-30 21:00:00
# --2025-10-22 15:49:36--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2022/07/02/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207022100.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3792886 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207022100.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.62M  6.89MB/s    in 0.5s
#
# 2025-10-22 15:49:37 (6.89 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207022100.nc’ saved [3792886/3792886]
#
# 2022-06-30 21:30:00
# --2025-10-22 15:49:38--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2022/07/02/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207022130.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3785695 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207022130.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.61M  7.80MB/s    in 0.5s
#
# 2025-10-22 15:49:39 (7.80 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207022130.nc’ saved [3785695/3785695]
#
# 2022-06-30 22:00:00
# --2025-10-22 15:49:39--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2022/07/02/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207022200.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3790048 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207022200.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.61M  7.02MB/s    in 0.5s
#
# 2025-10-22 15:49:40 (7.02 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207022200.nc’ saved [3790048/3790048]
#
# 2022-06-30 22:30:00
# --2025-10-22 15:49:40--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2022/07/02/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207022230.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3791362 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207022230.nc’
#
# NETCDF4_LSASAF_MSG_   3%[                    ] 112.00K  --.-KB/s    in 17m 12s
#
# 2025-10-22 16:08:03 (111 B/s) - Read error at byte 114688/3791362 (Connection timed out). Retrying.
#
# --2025-10-22 16:08:04--  (try: 2)  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2022/07/02/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207022230.nc
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 206 Partial Content
# Length: 3791362 (3.6M), 3676674 (3.5M) remaining [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207022230.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.62M   744KB/s    in 4.8s
#
# 2025-10-22 16:09:24 (744 KB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207022230.nc’ saved [3791362/3791362]
#
# 2022-06-30 23:00:00
# --2025-10-22 16:09:24--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2022/07/02/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207022300.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3788194 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207022300.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.61M  1014KB/s    in 10s
#
# 2025-10-22 16:09:45 (367 KB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207022300.nc’ saved [3788194/3788194]
#
# 2022-06-30 23:30:00
# --2025-10-22 16:09:45--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2022/07/02/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207022330.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3788348 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207022330.nc’
#
# NETCDF4_LSASAF_MSG_  68%[============>       ]   2.47M   776KB/s    in 4m 34s
#
# 2025-10-22 16:14:45 (9.23 KB/s) - Connection closed at byte 2593984. Retrying.
#
# --2025-10-22 16:14:46--  (try: 2)  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2022/07/02/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207022330.nc
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 206 Partial Content
# Length: 3788348 (3.6M), 1194364 (1.1M) remaining [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207022330.nc’
#
# NETCDF4_LSASAF_MSG_  90%[+++++++++++++====>  ]   3.29M  --.-KB/s    in 46s
#
# 2025-10-22 16:15:36 (18.2 KB/s) - Read error at byte 3445952/3788348 (Connection reset by peer). Retrying.
#
# --2025-10-22 16:15:38--  (try: 3)  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2022/07/02/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207022330.nc
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# Unable to establish SSL connection.
# 2022-06-30 00:00:00
# --2025-10-22 16:18:27--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2022/07/03/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207030000.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3798656 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207030000.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.62M   484KB/s    in 7.7s
#
# 2025-10-22 16:21:39 (484 KB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207030000.nc’ saved [3798656/3798656]
#
# 2022-06-30 00:30:00
# --2025-10-22 16:21:39--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2022/07/03/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207030030.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3791700 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207030030.nc’
#
# NETCDF4_LSASAF_MSG_   0%[                    ]       0  --.-KB/s    in 15m 0s
#
# 2025-10-22 16:39:14 (0.00 B/s) - Read error at byte 0/3791700 (Connection timed out). Retrying.
#
# --2025-10-22 16:39:15--  (try: 2)  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2022/07/03/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207030030.nc
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... failed: Connection timed out.
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3791700 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207030030.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[===================>]   3.62M  1.60MB/s    in 2.3s
#
# 2025-10-22 16:44:37 (1.60 MB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207030030.nc’ saved [3791700/3791700]
#
# 2022-06-30 01:00:00
# --2025-10-22 16:44:37--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2022/07/03/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207030100.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... No data received.
# Retrying.
#
# --2025-10-22 16:52:09--  (try: 2)  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2022/07/03/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207030100.nc
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3789901 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207030100.nc’
#
# NETCDF4_LSASAF_MSG_  57%[==========>         ]   2.08M   999KB/s    in 2m 38s
#
# 2025-10-22 16:58:01 (13.4 KB/s) - Connection closed at byte 2177288. Retrying.
#
# --2025-10-22 16:58:03--  (try: 3)  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2022/07/03/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207030100.nc
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... failed: Connection timed out.
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... failed: Connection timed out.
# Retrying.
#
# --2025-10-22 17:02:28--  (try: 4)  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2022/07/03/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207030100.nc
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 206 Partial Content
# Length: 3789901 (3.6M), 1612613 (1.5M) remaining [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207030100.nc’
#
# NETCDF4_LSASAF_MSG_  58%[+++++++++++         ]   2.10M  --.-KB/s    in 15m 2s
#
# 2025-10-22 17:17:48 (27.2 B/s) - Read error at byte 2201864/3789901 (Connection timed out). Retrying.
#
# --2025-10-22 17:17:52--  (try: 5)  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2022/07/03/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207030100.nc
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 206 Partial Content
# Length: 3789901 (3.6M), 1588037 (1.5M) remaining [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207030100.nc’
#
# NETCDF4_LSASAF_MSG_ 100%[+++++++++++========>]   3.61M   843KB/s    in 33s
#
# 2025-10-22 17:20:36 (46.7 KB/s) - ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207030100.nc’ saved [3789901/3789901]
#
# 2022-06-30 01:30:00
# --2025-10-22 17:20:37--  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2022/07/03/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207030130.nc
# Resolving datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)... 193.137.20.109
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="Restricted"
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3788068 (3.6M) [application/octet-stream]
# Saving to: ‘data/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207030130.nc’
#
# NETCDF4_LSASAF_MSG_   1%[                    ]  52.46K  --.-KB/s    in 15m 14s
#
# 2025-10-22 17:39:36 (58.8 B/s) - Read error at byte 53720/3788068 (Connection timed out). Retrying.
#
# --2025-10-22 17:39:37--  (try: 2)  https://datalsasaf.lsasvcs.ipma.pt/PRODUCTS/MSG/MLST-ASv2/NETCDF/2022/07/03/NETCDF4_LSASAF_MSG_MLST-ASv2_MSG-Disk_202207030130.nc
# Connecting to datalsasaf.lsasvcs.ipma.pt (datalsasaf.lsasvcs.ipma.pt)|193.137.20.109|:443... connected.

# %% [markdown]
# <hr>

# %% [markdown]
# <hr>

# %% [markdown]
# <span style=float:center><img src='../img/LSASAF_Name_Colour.png' alt='LSA SAF' align='right' width='20%'></img>
# <span style=float:center><img src='../img/eumet_logo.png' alt='Eumetsat logo' align='center' width='20%'></img>
